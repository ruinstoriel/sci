# %%
import jieba 
jieba.load_userdict("./ke_dict.txt")

seg_list = jieba.cut("iPhone16E手机壳磨砂磁吸原装15PROMAX/14/13/12/11/XR/XS/7P/8P/SE冰雾肤感磁吸防")
l = ["iPhone16E","手机壳","11","SE","15PROMAX","14","15"]
filter(lambda x:x)
print(", ".join(seg_list))
# Out:
# iPhone16E, 手机壳, 磨砂, 磁吸, 原装, 15PROMAX, /, 14, /, 13, /, 12, /, 11, /, XR, /, XS, /, 7P, /, 8P, /, SE, 冰雾, 肤感, 磁吸防
