# %%
import pandas as pd
import os.path as path
p = "C:/Users/toriel/Desktop/OEMG巨溪成都发4.1订单(1).xlsx"
name = path.basename(p)
df = pd.read_excel(p, sheet_name="快递订单", header=0, usecols=["商品名称","商品数量"])
df = df.groupby("商品名称")["商品数量"].sum().reset_index()
df['名称'] = name
df
# Out:
#                  商品名称  商品数量                      名称
# 0        Y农家特产孢子粉500g     2  OEMG巨溪成都发4.1订单(1).xlsx
# 1         Y特产干货蒲公英50g     1  OEMG巨溪成都发4.1订单(1).xlsx
# 2   [买一送一专属]特产乌天麻250g    41  OEMG巨溪成都发4.1订单(1).xlsx
# 3        h农家特产桑葚干500g     6  OEMG巨溪成都发4.1订单(1).xlsx
# 4        h特产灵芝孢子粉500g     3  OEMG巨溪成都发4.1订单(1).xlsx
# 5       x农家特产叶子红糖500g     4  OEMG巨溪成都发4.1订单(1).xlsx
# 6     x农家特产葛根粉250g*2罐     9  OEMG巨溪成都发4.1订单(1).xlsx
# 7         x农家特产雪燕250g     1  OEMG巨溪成都发4.1订单(1).xlsx
# 8       优选农家虫草花100g/包     1  OEMG巨溪成都发4.1订单(1).xlsx
# 9        优选特产金桔干 250g     1  OEMG巨溪成都发4.1订单(1).xlsx
# 10          农家乌天麻250g    40  OEMG巨溪成都发4.1订单(1).xlsx
# 11       农家优选青花椒50g/包     1  OEMG巨溪成都发4.1订单(1).xlsx
# 12       农家古法叶子红糖500g     1  OEMG巨溪成都发4.1订单(1).xlsx
# 13      农家特产 枇杷果干250g     1  OEMG巨溪成都发4.1订单(1).xlsx
# 14       农家特产乌天麻块500g    23  OEMG巨溪成都发4.1订单(1).xlsx
# 15        农家特产小银耳250g     2  OEMG巨溪成都发4.1订单(1).xlsx
# 16      农家特产红枣切片50g/包     5  OEMG巨溪成都发4.1订单(1).xlsx
# ...

# %%
import os.path as path
p = "C:/Users/toriel/Desktop/OEMG巨溪成都发4.1订单(1).xlsx"
path.basename(p)
# Out:
# 'OEMG巨溪成都发4.1订单(1).xlsx'

# %%
a=[1,2]
print(a[0:1])
# Out:
# [1]
